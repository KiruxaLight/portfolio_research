# %%
import pandas as pd
import pickle

# %% [markdown]
# ### Raw
# #### Dow Jones

# %%
tickers_dow = sorted(['UNH', 'MSFT', 'GS', 'HD', 'AMGN', 'MCD', 'CAT', 'CRM', 'BA', 'TRV', 'HON', 'V', 'AAPL', 'AXP', 'IBM', 'JPM', 'JNJ', 'WMT', 'PG', 'CVX', 'MRK', 'MMM', 'NKE', 'DIS', 'KO', 'DOW', 'CSCO', 'INTC', 'VZ', 'WBA'])
tickers_dow
# Out:
# ['AAPL',
#  'AMGN',
#  'AXP',
#  'BA',
#  'CAT',
#  'CRM',
#  'CSCO',
#  'CVX',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'KO',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'V',
#  'VZ',
#  'WBA',
#  'WMT']

# %% [markdown]
# #### FTSE 100

# %%
df_ftse = pd.read_csv("ftse.csv", header=None)
tickers_ftse = list(df_ftse[0])
tickers_ftse
# Out:
# ['III',
#  'ADM',
#  'AAF.L',
#  'AAL',
#  'ANTO.L',
#  'AHT',
#  'AZN',
#  'AUTO.L',
#  'AV.L',
#  'BME',
#  'BA.L',
#  'BARC.L',
#  'BDEV.L',
#  'BEZ.L',
#  'BKY.L',
#  'BP',
#  'BATS.L',
#  'BT-A.L',
#  'BNZL.L',
#  'BRBY.L',
#  'CNA',
#  'CCH.L',
#  'CPG',
#  'CTEC',
#  'CRDA.L',
#  'DCC.L',
#  'DGE',
#  'DPLM.L',
#  'EDV',
#  'ENT.L',
#  'EXPN.L',
#  'FCIT.L',
#  'FLTR',
#  'FRAS.L',
#  'FRES',
#  'GLEN.L',
#  'GSK',
#  'HLMA.L',
#  'HIK',
#  'HWDN.L',
#  'HSBA.L',
#  'IMB.L',
#  'INF.L',
#  'IHG',
#  'ICP.L',
#  'ITRK.L',
#  'IAG',
#  'JD',
#  'LAND',
#  'LLOY.L',
#  'LSEG.L',
#  'MNG',
#  'MKS.L',
#  'MRO',
#  'MNDI.L',
#  'NG',
#  'NWG',
#  'NXT.L',
#  'OCDO.L',
#  'PSON.L',
#  'PSHZF',
#  'PSN',
#  'PHNX.L',
#  'PRU',
#  'RKT',
#  'REL.L',
#  'RTO',
#  'RMV.L',
#  'RIO',
#  'RR.L',
#  'RS1.L',
#  'SGE.L',
#  'SBRY.L',
#  'SDR.L',
#  'SMT.L',
#  'SGRO.L',
#  'SVT',
#  'SHEL',
#  'SMDS.L',
#  'SMIN',
#  'SKG',
#  'SPXSY',
#  'SSE.L',
#  'STJ.L',
#  'STAN.L',
#  'TW',
#  'TSCO',
#  'ULVR.L',
#  'UTG',
#  'UU.L',
#  'VOD',
#  'WEIR.L',
#  'WTB.L',
#  'WPP']

# %% [markdown]
# #### NASDAQ

# %%
df_nasdaq = pd.read_csv("nasdaq.txt", header=None)
tickers_nasdaq = list(df_nasdaq[0])
tickers_nasdaq
# Out:
# ['AAPL',
#  'ABNB',
#  'ADBE',
#  'ADI',
#  'ADP',
#  'ADSK',
#  'AEP',
#  'AMAT',
#  'AMD',
#  'AMGN',
#  'AMZN',
#  'ANSS',
#  'ASML',
#  'AVGO',
#  'AZN',
#  'BIIB',
#  'BKNG',
#  'BKR',
#  'CCEP',
#  'CDNS',
#  'CDW',
#  'CHTR',
#  'CMCSA',
#  'COST',
#  'CPRT',
#  'CRWD',
#  'CSCO',
#  'CSGP',
#  'CSX',
#  'CTAS',
#  'CTSH',
#  'DASH',
#  'DDOG',
#  'DLTR',
#  'DXCM',
#  'EA',
#  'EXC',
#  'FANG',
#  'FAST',
#  'FTNT',
#  'GFS',
#  'GILD',
#  'GOOG',
#  'GOOGL',
#  'HON',
#  'IDXX',
#  'ILMN',
#  'INTC',
#  'INTU',
#  'ISRG',
#  'KDP',
#  'KHC',
#  'KLAC',
#  'LRCX',
#  'LULU',
#  'MAR',
#  'MCHP',
#  'MDB',
#  'MDLZ',
#  'MELI',
#  'META',
#  'MNST',
#  'MRNA',
#  'MRVL',
#  'MSFT',
#  'MU',
#  'NFLX',
#  'NVDA',
#  'NXPI',
#  'ODFL',
#  'ON',
#  'ORLY',
#  'PANW',
#  'PAYX',
#  'PCAR',
#  'PDD',
#  'PEP',
#  'PYPL',
#  'QCOM',
#  'REGN',
#  'ROP',
#  'ROST',
#  'SBAC',
#  'SBUX',
#  'SIRI',
#  'SNPS',
#  'SPLK',
#  'TEAM',
#  'TMUS',
#  'TSLA',
#  'TTD',
#  'TTWO',
#  'TXN',
#  'VRSK',
#  'VRTX',
#  'WBA',
#  'WBD',
#  'WDAY',
#  'XEL',
#  'ZS']

# %% [markdown]
# #### S&P 500

# %%
df_snp = pd.read_csv("snp.csv", header=None)
tickers_snp = list(df_snp[0])
tickers_snp
# Out:
# ['MSFT',
#  'AAPL',
#  'NVDA',
#  'AMZN',
#  'META',
#  'GOOGL',
#  'BRK-B',
#  'GOOG',
#  'LLY',
#  'AVGO',
#  'TSLA',
#  'JPM',
#  'UNH',
#  'V',
#  'XOM',
#  'MA',
#  'JNJ',
#  'PG',
#  'HD',
#  'MRK',
#  'COST',
#  'ABBV',
#  'AMD',
#  'CRM',
#  'CVX',
#  'NFLX',
#  'WMT',
#  'ADBE',
#  'KO',
#  'ACN',
#  'BAC',
#  'PEP',
#  'LIN',
#  'TMO',
#  'MCD',
#  'ABT',
#  'DIS',
#  'CSCO',
#  'WFC',
#  'INTU',
#  'INTC',
#  'ORCL',
#  'QCOM',
#  'VZ',
#  'CMCSA',
#  'IBM',
#  'AMAT',
#  'DHR',
#  'GE',
#  'CAT',
#  'UBER',
#  'NOW',
#  'PFE',
#  'UNP',
#  'AMGN',
#  'TXN',
#  'PM',
#  'SPGI',
#  'ISRG',
#  'BKNG',
#  'COP',
#  'LOW',
#  'HON',
#  'RTX',
#  'NKE',
#  'GS',
#  'LRCX',
#  'PLD',
#  'AXP',
#  'ELV',
#  'SYK',
#  'T',
#  'NEE',
#  'BA',
#  'BLK',
#  'ETN',
#  'TJX',
#  'MDT',
#  'PGR',
#  'VRTX',
#  'SBUX',
#  'MS',
#  'UPS',
#  'C',
#  'ADP',
#  'BMY',
#  'CB',
#  'REGN',
#  'MDLZ',
#  'MMC',
#  'CI',
#  'CVS',
#  'BSX',
#  'SCHW',
#  'ADI',
#  'DE',
#  'LMT',
#  'MU',
#  'KLAC',
#  'GILD',
#  'BX',
#  'ZTS',
#  'FI',
#  'SNPS',
#  'AMT',
#  'PANW',
#  'TMUS',
#  'CDNS',
#  'EQIX',
#  'ICE',
#  'CME',
#  'WM',
#  'SHW',
#  'CSX',
#  'SO',
#  'MO',
#  'CMG',
#  'DUK',
#  'ITW',
#  'CL',
#  'BDX',
#  'SLB',
#  'TGT',
#  'PH',
#  'MCK',
#  'EOG',
#  'ANET',
#  'ABNB',
#  'TDG',
#  'NOC',
#  'PSX',
#  'TT',
#  'USB',
#  'MPC',
#  'APH',
#  'AON',
#  'PYPL',
#  'ORLY',
#  'HCA',
#  'NXPI',
#  'GD',
#  'MAR',
#  'MCO',
#  'EMR',
#  'ROP',
#  'NSC',
#  'PNC',
#  'PCAR',
#  'FDX',
#  'ECL',
#  'FCX',
#  'MSI',
#  'ADSK',
#  'PXD',
#  'CTAS',
#  'GM',
#  'EW',
#  'AJG',
#  'LULU',
#  'WELL',
#  'HLT',
#  'APD',
#  'COF',
#  'MMM',
#  'TRV',
#  'AIG',
#  'ROST',
#  'SPG',
#  'AZO',
#  'F',
#  'VLO',
#  'IDXX',
#  'TFC',
#  'CCI',
#  'NUE',
#  'DXCM',
#  'MCHP',
#  'IQV',
#  'HUM',
#  'PSA',
#  'CARR',
#  'SRE',
#  'MSCI',
#  'URI',
#  'TEL',
#  'O',
#  'DHI',
#  'AEP',
#  'CPRT',
#  'OKE',
#  'MET',
#  'CNC',
#  'FTNT',
#  'CEG',
#  'BK',
#  'WMB',
#  'AFL',
#  'GWW',
#  'ALL',
#  'DLR',
#  'HES',
#  'FAST',
#  'AME',
#  'KMB',
#  'AMP',
#  'MNST',
#  'SYY',
#  'LHX',
#  'PAYX',
#  'OXY',
#  'CTSH',
#  'STZ',
#  'JCI',
#  'DOW',
#  'PRU',
#  'COR',
#  'ODFL',
#  'A',
#  'YUM',
#  'CTVA',
#  'LEN',
#  'D',
#  'FIS',
#  'GIS',
#  'OTIS',
#  'RSG',
#  'CMI',
#  'IR',
#  'EXC',
#  'NEM',
#  'MPWR',
#  'IT',
#  'EA',
#  'PCG',
#  'VRSK',
#  'EL',
#  'GPN',
#  'GEHC',
#  'VMC',
#  'MLM',
#  'PWR',
#  'ON',
#  'PPG',
#  'CSGP',
#  'KMI',
#  'CDW',
#  'KVUE',
#  'MRNA',
#  'XEL',
#  'EFX',
#  'BIIB',
#  'ROK',
#  'FICO',
#  'ACGL',
#  'FANG',
#  'HAL',
#  'KR',
#  'DG',
#  'VICI',
#  'KDP',
#  'ED',
#  'DLTR',
#  'FTV',
#  'PEG',
#  'DD',
#  'DFS',
#  'XYL',
#  'EXR',
#  'CHTR',
#  'ANSS',
#  'BKR',
#  'HSY',
#  'KHC',
#  'RCL',
#  'ADM',
#  'WTW',
#  'HIG',
#  'DVN',
#  'CBRE',
#  'DAL',
#  'ZBH',
#  'RMD',
#  'ULTA',
#  'WST',
#  'KEYS',
#  'CAH',
#  'MTD',
#  'EIX',
#  'TSCO',
#  'HWM',
#  'HPQ',
#  'LYB',
#  'GLW',
#  'TROW',
#  'WAB',
#  'AVB',
#  'WEC',
#  'WY',
#  'CHD',
#  'TTWO',
#  'NVR',
#  'BR',
#  'MOH',
#  'STE',
#  'BLDR',
#  'AWK',
#  'EBAY',
#  'MTB',
#  'DOV',
#  'FITB',
#  'SBAC',
#  'ALGN',
#  'PHM',
#  'STT',
#  'RJF',
#  'DTE',
#  'APTV',
#  'TRGP',
#  'ETR',
#  'ILMN',
#  'PTC',
#  'BAX',
#  'WBD',
#  'IRM',
#  'EQR',
#  'CBOE',
#  'GRMN',
#  'GPC',
#  'LUV',
#  'ES',
#  'IFF',
#  'TDY',
#  'DRI',
#  'FLT',
#  'BRO',
#  'LVS',
#  'CTRA',
#  'PPL',
#  'WAT',
#  'HUBB',
#  'COO',
#  'BALL',
#  'HPE',
#  'FE',
#  'AXON',
#  'NDAQ',
#  'INVH',
#  'STLD',
#  'CLX',
#  'ARE',
#  'VLTO',
#  'HOLX',
#  'EXPE',
#  'LH',
#  'HBAN',
#  'J',
#  'AEE',
#  'TYL',
#  'NTAP',
#  'JBL',
#  'WDC',
#  'VTR',
#  'IEX',
#  'PFG',
#  'CNP',
#  'CINF',
#  'EXPD',
#  'OMC',
#  'AVY',
#  'WRB',
#  'EPAM',
#  'FDS',
#  'VRSN',
#  'JBHT',
#  'MKC',
#  'LDOS',
#  'STX',
#  'RF',
#  'ATO',
#  'ENPH',
#  'SWKS',
#  'MAS',
#  'TXT',
#  'CMS',
#  'NTRS',
#  'SYF',
#  'AKAM',
#  'VTRS',
#  'EG',
#  'TER',
#  'PKG',
#  'WBA',
#  'FSLR',
#  'EQT',
#  'CCL',
#  'TRMB',
#  'CF',
#  'TSN',
#  'K',
#  'DPZ',
#  'LW',
#  'CE',
#  'UAL',
#  'ESS',
#  'NDSN',
#  'MAA',
#  'POOL',
#  'BBY',
#  'HST',
#  'CFG',
#  'ZBRA',
#  'SNA',
#  'MRO',
#  'DGX',
#  'LKQ',
#  'ALB',
#  'PODD',
#  'L',
#  'BG',
#  'SWK',
#  'KEY',
#  'CAG',
#  'AMCR',
#  'LYV',
#  'RVTY',
#  'SJM',
#  'JKHY',
#  'CRL',
#  'IPG',
#  'PNR',
#  'LNT',
#  'GEN',
#  'KIM',
#  'IP',
#  'JNPR',
#  'ROL',
#  'NRG',
#  'TAP',
#  'MGM',
#  'EVRG',
#  'KMX',
#  'HII',
#  'ALLE',
#  'INCY',
#  'TECH',
#  'TFX',
#  'WRK',
#  'QRVO',
#  'DAY',
#  'FFIV',
#  'UDR',
#  'TPR',
#  'GL',
#  'AES',
#  'BBWI',
#  'CTLT',
#  'NI',
#  'MOS',
#  'BF-B',
#  'EMN',
#  'CPT',
#  'NWSA',
#  'HSIC',
#  'REG',
#  'UHS',
#  'AAL',
#  'AOS',
#  'WYNN',
#  'MTCH',
#  'AIZ',
#  'APA',
#  'PEAK',
#  'BXP',
#  'PAYC',
#  'CZR',
#  'HRL',
#  'CHRW',
#  'ETSY',
#  'RHI',
#  'CPB',
#  'MKTX',
#  'PNW',
#  'BEN',
#  'RL',
#  'FOXA',
#  'FRT',
#  'BWA',
#  'XRAY',
#  'BIO',
#  'IVZ',
#  'GNRC',
#  'NCLH',
#  'DVA',
#  'CMA',
#  'FMC',
#  'HAS',
#  'WHR',
#  'ZION',
#  'MHK',
#  'PARA',
#  'VFC',
#  'FOX',
#  'NWS']

# %% [markdown]
# ### Dict

# %%
tickers_dict = {
    "dow": tickers_dow,
    "ftse": tickers_ftse,
    "nasdaq": tickers_nasdaq,
    "snp": tickers_snp
}

tickers_dict
# Out:
# {'dow': ['AAPL',
#   'AMGN',
#   'AXP',
#   'BA',
#   'CAT',
#   'CRM',
#   'CSCO',
#   'CVX',
#   'DIS',
#   'DOW',
#   'GS',
#   'HD',
#   'HON',
#   'IBM',
#   'INTC',
#   'JNJ',
#   'JPM',
#   'KO',
#   'MCD',
#   'MMM',
#   'MRK',
#   'MSFT',
#   'NKE',
#   'PG',
#   'TRV',
#   'UNH',
#   'V',
#   'VZ',
#   'WBA',
#   'WMT'],
#  'ftse': ['III',
#   'ADM',
#   'AAF.L',
#   'AAL',
#   'ANTO.L',
#   'AHT',
#   'AZN',
#   'AUTO.L',
#   'AV.L',
#   'BME',
#   'BA.L',
#   'BARC.L',
#   'BDEV.L',
#   'BEZ.L',
#   'BKY.L',
#   'BP',
#   'BATS.L',
#   'BT-A.L',
#   'BNZL.L',
#   'BRBY.L',
#   'CNA',
#   'CCH.L',
#   'CPG',
#   'CTEC',
#   'CRDA.L',
#   'DCC.L',
#   'DGE',
#   'DPLM.L',
#   'EDV',
#   'ENT.L',
#   'EXPN.L',
#   'FCIT.L',
#   'FLTR',
#   'FRAS.L',
#   'FRES',
#   'GLEN.L',
#   'GSK',
#   'HLMA.L',
#   'HIK',
#   'HWDN.L',
#   'HSBA.L',
#   'IMB.L',
#   'INF.L',
#   'IHG',
#   'ICP.L',
#   'ITRK.L',
#   'IAG',
#   'JD',
#   'LAND',
#   'LLOY.L',
#   'LSEG.L',
#   'MNG',
#   'MKS.L',
#   'MRO',
#   'MNDI.L',
#   'NG',
#   'NWG',
#   'NXT.L',
#   'OCDO.L',
#   'PSON.L',
#   'PSHZF',
#   'PSN',
#   'PHNX.L',
#   'PRU',
#   'RKT',
#   'REL.L',
#   'RTO',
#   'RMV.L',
#   'RIO',
#   'RR.L',
#   'RS1.L',
#   'SGE.L',
#   'SBRY.L',
#   'SDR.L',
#   'SMT.L',
#   'SGRO.L',
#   'SVT',
#   'SHEL',
#   'SMDS.L',
#   'SMIN',
#   'SKG',
#   'SPXSY',
#   'SSE.L',
#   'STJ.L',
#   'STAN.L',
#   'TW',
#   'TSCO',
#   'ULVR.L',
#   'UTG',
#   'UU.L',
#   'VOD',
#   'WEIR.L',
#   'WTB.L',
#   'WPP'],
#  'nasdaq': ['AAPL',
#   'ABNB',
#   'ADBE',
#   'ADI',
#   'ADP',
#   'ADSK',
#   'AEP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'AMZN',
#   'ANSS',
#   'ASML',
#   'AVGO',
#   'AZN',
#   'BIIB',
#   'BKNG',
#   'BKR',
#   'CCEP',
#   'CDNS',
#   'CDW',
#   'CHTR',
#   'CMCSA',
#   'COST',
#   'CPRT',
#   'CRWD',
#   'CSCO',
#   'CSGP',
#   'CSX',
#   'CTAS',
#   'CTSH',
#   'DASH',
#   'DDOG',
#   'DLTR',
#   'DXCM',
#   'EA',
#   'EXC',
#   'FANG',
#   'FAST',
#   'FTNT',
#   'GFS',
#   'GILD',
#   'GOOG',
#   'GOOGL',
#   'HON',
#   'IDXX',
#   'ILMN',
#   'INTC',
#   'INTU',
#   'ISRG',
#   'KDP',
#   'KHC',
#   'KLAC',
#   'LRCX',
#   'LULU',
#   'MAR',
#   'MCHP',
#   'MDB',
#   'MDLZ',
#   'MELI',
#   'META',
#   'MNST',
#   'MRNA',
#   'MRVL',
#   'MSFT',
#   'MU',
#   'NFLX',
#   'NVDA',
#   'NXPI',
#   'ODFL',
#   'ON',
#   'ORLY',
#   'PANW',
#   'PAYX',
#   'PCAR',
#   'PDD',
#   'PEP',
#   'PYPL',
#   'QCOM',
#   'REGN',
#   'ROP',
#   'ROST',
#   'SBAC',
#   'SBUX',
#   'SIRI',
#   'SNPS',
#   'SPLK',
#   'TEAM',
#   'TMUS',
#   'TSLA',
#   'TTD',
#   'TTWO',
#   'TXN',
#   'VRSK',
#   'VRTX',
#   'WBA',
#   'WBD',
#   'WDAY',
#   'XEL',
#   'ZS'],
#  'snp': ['MSFT',
#   'AAPL',
#   'NVDA',
#   'AMZN',
#   'META',
#   'GOOGL',
#   'BRK-B',
#   'GOOG',
#   'LLY',
#   'AVGO',
#   'TSLA',
#   'JPM',
#   'UNH',
#   'V',
#   'XOM',
#   'MA',
#   'JNJ',
#   'PG',
#   'HD',
#   'MRK',
#   'COST',
#   'ABBV',
#   'AMD',
#   'CRM',
#   'CVX',
#   'NFLX',
#   'WMT',
#   'ADBE',
#   'KO',
#   'ACN',
#   'BAC',
#   'PEP',
#   'LIN',
#   'TMO',
#   'MCD',
#   'ABT',
#   'DIS',
#   'CSCO',
#   'WFC',
#   'INTU',
#   'INTC',
#   'ORCL',
#   'QCOM',
#   'VZ',
#   'CMCSA',
#   'IBM',
#   'AMAT',
#   'DHR',
#   'GE',
#   'CAT',
#   'UBER',
#   'NOW',
#   'PFE',
#   'UNP',
#   'AMGN',
#   'TXN',
#   'PM',
#   'SPGI',
#   'ISRG',
#   'BKNG',
#   'COP',
#   'LOW',
#   'HON',
#   'RTX',
#   'NKE',
#   'GS',
#   'LRCX',
#   'PLD',
#   'AXP',
#   'ELV',
#   'SYK',
#   'T',
#   'NEE',
#   'BA',
#   'BLK',
#   'ETN',
#   'TJX',
#   'MDT',
#   'PGR',
#   'VRTX',
#   'SBUX',
#   'MS',
#   'UPS',
#   'C',
#   'ADP',
#   'BMY',
#   'CB',
#   'REGN',
#   'MDLZ',
#   'MMC',
#   'CI',
#   'CVS',
#   'BSX',
#   'SCHW',
#   'ADI',
#   'DE',
#   'LMT',
#   'MU',
#   'KLAC',
#   'GILD',
#   'BX',
#   'ZTS',
#   'FI',
#   'SNPS',
#   'AMT',
#   'PANW',
#   'TMUS',
#   'CDNS',
#   'EQIX',
#   'ICE',
#   'CME',
#   'WM',
#   'SHW',
#   'CSX',
#   'SO',
#   'MO',
#   'CMG',
#   'DUK',
#   'ITW',
#   'CL',
#   'BDX',
#   'SLB',
#   'TGT',
#   'PH',
#   'MCK',
#   'EOG',
#   'ANET',
#   'ABNB',
#   'TDG',
#   'NOC',
#   'PSX',
#   'TT',
#   'USB',
#   'MPC',
#   'APH',
#   'AON',
#   'PYPL',
#   'ORLY',
#   'HCA',
#   'NXPI',
#   'GD',
#   'MAR',
#   'MCO',
#   'EMR',
#   'ROP',
#   'NSC',
#   'PNC',
#   'PCAR',
#   'FDX',
#   'ECL',
#   'FCX',
#   'MSI',
#   'ADSK',
#   'PXD',
#   'CTAS',
#   'GM',
#   'EW',
#   'AJG',
#   'LULU',
#   'WELL',
#   'HLT',
#   'APD',
#   'COF',
#   'MMM',
#   'TRV',
#   'AIG',
#   'ROST',
#   'SPG',
#   'AZO',
#   'F',
#   'VLO',
#   'IDXX',
#   'TFC',
#   'CCI',
#   'NUE',
#   'DXCM',
#   'MCHP',
#   'IQV',
#   'HUM',
#   'PSA',
#   'CARR',
#   'SRE',
#   'MSCI',
#   'URI',
#   'TEL',
#   'O',
#   'DHI',
#   'AEP',
#   'CPRT',
#   'OKE',
#   'MET',
#   'CNC',
#   'FTNT',
#   'CEG',
#   'BK',
#   'WMB',
#   'AFL',
#   'GWW',
#   'ALL',
#   'DLR',
#   'HES',
#   'FAST',
#   'AME',
#   'KMB',
#   'AMP',
#   'MNST',
#   'SYY',
#   'LHX',
#   'PAYX',
#   'OXY',
#   'CTSH',
#   'STZ',
#   'JCI',
#   'DOW',
#   'PRU',
#   'COR',
#   'ODFL',
#   'A',
#   'YUM',
#   'CTVA',
#   'LEN',
#   'D',
#   'FIS',
#   'GIS',
#   'OTIS',
#   'RSG',
#   'CMI',
#   'IR',
#   'EXC',
#   'NEM',
#   'MPWR',
#   'IT',
#   'EA',
#   'PCG',
#   'VRSK',
#   'EL',
#   'GPN',
#   'GEHC',
#   'VMC',
#   'MLM',
#   'PWR',
#   'ON',
#   'PPG',
#   'CSGP',
#   'KMI',
#   'CDW',
#   'KVUE',
#   'MRNA',
#   'XEL',
#   'EFX',
#   'BIIB',
#   'ROK',
#   'FICO',
#   'ACGL',
#   'FANG',
#   'HAL',
#   'KR',
#   'DG',
#   'VICI',
#   'KDP',
#   'ED',
#   'DLTR',
#   'FTV',
#   'PEG',
#   'DD',
#   'DFS',
#   'XYL',
#   'EXR',
#   'CHTR',
#   'ANSS',
#   'BKR',
#   'HSY',
#   'KHC',
#   'RCL',
#   'ADM',
#   'WTW',
#   'HIG',
#   'DVN',
#   'CBRE',
#   'DAL',
#   'ZBH',
#   'RMD',
#   'ULTA',
#   'WST',
#   'KEYS',
#   'CAH',
#   'MTD',
#   'EIX',
#   'TSCO',
#   'HWM',
#   'HPQ',
#   'LYB',
#   'GLW',
#   'TROW',
#   'WAB',
#   'AVB',
#   'WEC',
#   'WY',
#   'CHD',
#   'TTWO',
#   'NVR',
#   'BR',
#   'MOH',
#   'STE',
#   'BLDR',
#   'AWK',
#   'EBAY',
#   'MTB',
#   'DOV',
#   'FITB',
#   'SBAC',
#   'ALGN',
#   'PHM',
#   'STT',
#   'RJF',
#   'DTE',
#   'APTV',
#   'TRGP',
#   'ETR',
#   'ILMN',
#   'PTC',
#   'BAX',
#   'WBD',
#   'IRM',
#   'EQR',
#   'CBOE',
#   'GRMN',
#   'GPC',
#   'LUV',
#   'ES',
#   'IFF',
#   'TDY',
#   'DRI',
#   'FLT',
#   'BRO',
#   'LVS',
#   'CTRA',
#   'PPL',
#   'WAT',
#   'HUBB',
#   'COO',
#   'BALL',
#   'HPE',
#   'FE',
#   'AXON',
#   'NDAQ',
#   'INVH',
#   'STLD',
#   'CLX',
#   'ARE',
#   'VLTO',
#   'HOLX',
#   'EXPE',
#   'LH',
#   'HBAN',
#   'J',
#   'AEE',
#   'TYL',
#   'NTAP',
#   'JBL',
#   'WDC',
#   'VTR',
#   'IEX',
#   'PFG',
#   'CNP',
#   'CINF',
#   'EXPD',
#   'OMC',
#   'AVY',
#   'WRB',
#   'EPAM',
#   'FDS',
#   'VRSN',
#   'JBHT',
#   'MKC',
#   'LDOS',
#   'STX',
#   'RF',
#   'ATO',
#   'ENPH',
#   'SWKS',
#   'MAS',
#   'TXT',
#   'CMS',
#   'NTRS',
#   'SYF',
#   'AKAM',
#   'VTRS',
#   'EG',
#   'TER',
#   'PKG',
#   'WBA',
#   'FSLR',
#   'EQT',
#   'CCL',
#   'TRMB',
#   'CF',
#   'TSN',
#   'K',
#   'DPZ',
#   'LW',
#   'CE',
#   'UAL',
#   'ESS',
#   'NDSN',
#   'MAA',
#   'POOL',
#   'BBY',
#   'HST',
#   'CFG',
#   'ZBRA',
#   'SNA',
#   'MRO',
#   'DGX',
#   'LKQ',
#   'ALB',
#   'PODD',
#   'L',
#   'BG',
#   'SWK',
#   'KEY',
#   'CAG',
#   'AMCR',
#   'LYV',
#   'RVTY',
#   'SJM',
#   'JKHY',
#   'CRL',
#   'IPG',
#   'PNR',
#   'LNT',
#   'GEN',
#   'KIM',
#   'IP',
#   'JNPR',
#   'ROL',
#   'NRG',
#   'TAP',
#   'MGM',
#   'EVRG',
#   'KMX',
#   'HII',
#   'ALLE',
#   'INCY',
#   'TECH',
#   'TFX',
#   'WRK',
#   'QRVO',
#   'DAY',
#   'FFIV',
#   'UDR',
#   'TPR',
#   'GL',
#   'AES',
#   'BBWI',
#   'CTLT',
#   'NI',
#   'MOS',
#   'BF-B',
#   'EMN',
#   'CPT',
#   'NWSA',
#   'HSIC',
#   'REG',
#   'UHS',
#   'AAL',
#   'AOS',
#   'WYNN',
#   'MTCH',
#   'AIZ',
#   'APA',
#   'PEAK',
#   'BXP',
#   'PAYC',
#   'CZR',
#   'HRL',
#   'CHRW',
#   'ETSY',
#   'RHI',
#   'CPB',
#   'MKTX',
#   'PNW',
#   'BEN',
#   'RL',
#   'FOXA',
#   'FRT',
#   'BWA',
#   'XRAY',
#   'BIO',
#   'IVZ',
#   'GNRC',
#   'NCLH',
#   'DVA',
#   'CMA',
#   'FMC',
#   'HAS',
#   'WHR',
#   'ZION',
#   'MHK',
#   'PARA',
#   'VFC',
#   'FOX',
#   'NWS']}

# %%
pickle.dump(tickers_dict, open("tickers_dict.pkl", "wb"))

# %% [markdown]
# ### Dataframe

# %%
list_dow = [["DOW", item] for item in tickers_dow]
list_ftse = [["FTSE", item] for item in tickers_ftse]
list_nasdaq = [["NASDAQ", item] for item in tickers_nasdaq]
list_snp = [["S&P", item] for item in tickers_snp]

# %%
df = pd.DataFrame(list_dow + list_ftse + list_nasdaq + list_snp, columns=["Index", "Ticker"])
df
# Out:
#     Index Ticker
# 0     DOW   AAPL
# 1     DOW   AMGN
# 2     DOW    AXP
# 3     DOW     BA
# 4     DOW    CAT
# ..    ...    ...
# 722   S&P    MHK
# 723   S&P   PARA
# 724   S&P    VFC
# 725   S&P    FOX
# 726   S&P    NWS
#
# [727 rows x 2 columns]

# %%
df.to_csv("tickers_df.csv", index=False)

# %% [markdown]
# ### Подключение библиотек

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
start_date = '2020-01-01'
end_date = '2024-01-01'
tickers = df['Ticker'].unique().tolist()
price_data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']
# Out:
# [*********************100%***********************]  608 of 608 completed
#
# 8 Failed downloads:
# ['PEAK', 'SPLK', 'CPG', 'FLT', 'ICP.L', 'WRK', 'PXD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['SPXSY']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2020-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1577854800, endDate = 1704085200")')

# %%
price_data
# Out:
# Ticker                              A       AAF.L        AAL        AAPL  \
# Date
# 2020-01-02 00:00:00+00:00   83.214882   62.851871  28.982893   72.796036
# 2020-01-03 00:00:00+00:00   81.878784   62.612579  27.548195   72.088303
# 2020-01-06 00:00:00+00:00   82.120827   62.572712  27.219410   72.662712
# 2020-01-07 00:00:00+00:00   82.372551   63.250687  27.119778   72.320984
# 2020-01-08 00:00:00+00:00   83.185829   62.014389  27.737495   73.484344
# ...                               ...         ...        ...         ...
# 2023-12-22 00:00:00+00:00  138.629990  123.879662  14.310000  192.656174
# 2023-12-26 00:00:00+00:00  138.868347         NaN  14.110000  192.108871
# 2023-12-27 00:00:00+00:00  138.878296  124.166649  13.990000  192.208359
# 2023-12-28 00:00:00+00:00  138.828629  123.783997  13.980000  192.636292
# 2023-12-29 00:00:00+00:00  138.327179  124.549278  13.740000  191.591385
#
# Ticker                           ABBV        ABNB         ABT       ACGL  \
# Date
# 2020-01-02 00:00:00+00:00   72.264885         NaN   79.689957  41.268997
# 2020-01-03 00:00:00+00:00   71.578957         NaN   78.718460  41.221451
# 2020-01-06 00:00:00+00:00   72.143837         NaN   79.130875  41.383106
# 2020-01-07 00:00:00+00:00   71.732269         NaN   78.690971  41.040779
# 2020-01-08 00:00:00+00:00   72.240677         NaN   79.011749  40.631893
# ...                               ...         ...         ...        ...
# 2023-12-22 00:00:00+00:00  149.475891  140.800003  106.896759  70.214340
# 2023-12-26 00:00:00+00:00  149.167175  138.720001  107.092850  69.900551
# 2023-12-27 00:00:00+00:00  149.418015  136.550003  107.641884  69.929077
# 2023-12-28 00:00:00+00:00  149.292603  137.000000  108.239960  70.423546
# 2023-12-29 00:00:00+00:00  149.504837  136.139999  107.916412  70.623230
#
# Ticker                            ACN        ADBE  ...        XEL        XOM  \
# Date                                               ...
# 2020-01-02 00:00:00+00:00  195.263580  334.429993  ...  54.000282  55.631165
# 2020-01-03 00:00:00+00:00  194.938354  331.809998  ...  54.259991  55.183926
# 2020-01-06 00:00:00+00:00  193.665451  333.709991  ...  54.182079  55.607639
# 2020-01-07 00:00:00+00:00  189.484161  333.390015  ...  54.069538  55.152534
# 2020-01-08 00:00:00+00:00  189.855881  337.869995  ...  54.017593  54.320824
# ...                               ...         ...  ...        ...        ...
# 2023-12-22 00:00:00+00:00  348.842224  598.750000  ...  59.755741  98.548378
# 2023-12-26 00:00:00+00:00  347.838318  598.260010  ...  59.938686  98.770790
# 2023-12-27 00:00:00+00:00  348.222198  596.080017  ...  59.754204  98.306625
# 2023-12-28 00:00:00+00:00  346.027466  595.520020  ...  60.094044  96.885109
# 2023-12-29 00:00:00+00:00  345.358246  596.599976  ...  60.113468  96.682037
#
# Ticker                          XRAY         XYL         YUM         ZBH  \
# Date
# 2020-01-02 00:00:00+00:00  53.422768   75.451172   93.541397  139.626221
# 2020-01-03 00:00:00+00:00  52.831589   75.895309   93.248436  139.261230
# 2020-01-06 00:00:00+00:00  53.122486   75.403938   93.193504  138.456451
# 2020-01-07 00:00:00+00:00  53.403999   75.120476   93.358307  138.334763
# 2020-01-08 00:00:00+00:00  53.967037   75.375587   93.523094  139.991226
# ...                              ...         ...         ...         ...
# 2023-12-22 00:00:00+00:00  34.478691  111.722412  128.081024  119.562080
# 2023-12-26 00:00:00+00:00  34.791954  112.694427  128.337189  120.655167
# 2023-12-27 00:00:00+00:00  34.880062  113.448242  128.908630  120.366989
# 2023-12-28 00:00:00+00:00  34.978340  113.388725  128.593369  120.863838
# 2023-12-29 00:00:00+00:00  34.978340  113.428398  128.731293  120.933403
#
# Ticker                           ZBRA       ZION          ZS         ZTS
# Date
# 2020-01-02 00:00:00+00:00  259.140015  44.052658   47.330002  129.208878
# 2020-01-03 00:00:00+00:00  256.049988  43.431015   47.380001  129.228149
# 2020-01-06 00:00:00+00:00  258.010010  42.901775   48.700001  128.236053
# 2020-01-07 00:00:00+00:00  256.470001  42.641357   48.400002  128.669464
# 2020-01-08 00:00:00+00:00  247.639999  43.061386   50.750000  128.390137
# ...                               ...        ...         ...         ...
# 2023-12-22 00:00:00+00:00  269.410004  42.445377  221.679993  193.067825
# 2023-12-26 00:00:00+00:00  275.500000  43.294289  224.589996  193.582733
# 2023-12-27 00:00:00+00:00  275.790009  42.937359  225.020004  194.968994
# 2023-12-28 00:00:00+00:00  275.350006  43.082058  224.440002  195.226456
# 2023-12-29 00:00:00+00:00  273.329987  42.319969  221.559998  195.434387
#
# [1030 rows x 608 columns]

# %%
print(price_data.isna().sum())
# Out:
# Ticker
# A        24
# AAF.L    23
# AAL      24
# AAPL     24
# ABBV     24
#          ..
# ZBH      24
# ZBRA     24
# ZION     24
# ZS       24
# ZTS      24
# Length: 608, dtype: int64

# %%
price_data = price_data.fillna(method='ffill').fillna(method='bfill')
# убрать надо из списка
price_data = price_data.dropna(axis=1)

print(price_data.isna().sum())
# Out:
# Ticker
# A        0
# AAF.L    0
# AAL      0
# AAPL     0
# ABBV     0
#         ..
# ZBH      0
# ZBRA     0
# ZION     0
# ZS       0
# ZTS      0
# Length: 600, dtype: int64
# /var/folders/61/yjmw6mls60x61r2qn_zv2m600000gn/T/ipykernel_46454/2514010700.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   price_data = price_data.fillna(method='ffill').fillna(method='bfill')

# %%
price_data
# Out:
# Ticker                              A       AAF.L        AAL        AAPL  \
# Date
# 2020-01-02 00:00:00+00:00   83.214882   62.851871  28.982893   72.796036
# 2020-01-03 00:00:00+00:00   81.878784   62.612579  27.548195   72.088303
# 2020-01-06 00:00:00+00:00   82.120827   62.572712  27.219410   72.662712
# 2020-01-07 00:00:00+00:00   82.372551   63.250687  27.119778   72.320984
# 2020-01-08 00:00:00+00:00   83.185829   62.014389  27.737495   73.484344
# ...                               ...         ...        ...         ...
# 2023-12-22 00:00:00+00:00  138.629990  123.879662  14.310000  192.656174
# 2023-12-26 00:00:00+00:00  138.868347  123.879662  14.110000  192.108871
# 2023-12-27 00:00:00+00:00  138.878296  124.166649  13.990000  192.208359
# 2023-12-28 00:00:00+00:00  138.828629  123.783997  13.980000  192.636292
# 2023-12-29 00:00:00+00:00  138.327179  124.549278  13.740000  191.591385
#
# Ticker                           ABBV        ABNB         ABT       ACGL  \
# Date
# 2020-01-02 00:00:00+00:00   72.264885  144.710007   79.689957  41.268997
# 2020-01-03 00:00:00+00:00   71.578957  144.710007   78.718460  41.221451
# 2020-01-06 00:00:00+00:00   72.143837  144.710007   79.130875  41.383106
# 2020-01-07 00:00:00+00:00   71.732269  144.710007   78.690971  41.040779
# 2020-01-08 00:00:00+00:00   72.240677  144.710007   79.011749  40.631893
# ...                               ...         ...         ...        ...
# 2023-12-22 00:00:00+00:00  149.475891  140.800003  106.896759  70.214340
# 2023-12-26 00:00:00+00:00  149.167175  138.720001  107.092850  69.900551
# 2023-12-27 00:00:00+00:00  149.418015  136.550003  107.641884  69.929077
# 2023-12-28 00:00:00+00:00  149.292603  137.000000  108.239960  70.423546
# 2023-12-29 00:00:00+00:00  149.504837  136.139999  107.916412  70.623230
#
# Ticker                            ACN        ADBE  ...        XEL        XOM  \
# Date                                               ...
# 2020-01-02 00:00:00+00:00  195.263580  334.429993  ...  54.000282  55.631165
# 2020-01-03 00:00:00+00:00  194.938354  331.809998  ...  54.259991  55.183926
# 2020-01-06 00:00:00+00:00  193.665451  333.709991  ...  54.182079  55.607639
# 2020-01-07 00:00:00+00:00  189.484161  333.390015  ...  54.069538  55.152534
# 2020-01-08 00:00:00+00:00  189.855881  337.869995  ...  54.017593  54.320824
# ...                               ...         ...  ...        ...        ...
# 2023-12-22 00:00:00+00:00  348.842224  598.750000  ...  59.755741  98.548378
# 2023-12-26 00:00:00+00:00  347.838318  598.260010  ...  59.938686  98.770790
# 2023-12-27 00:00:00+00:00  348.222198  596.080017  ...  59.754204  98.306625
# 2023-12-28 00:00:00+00:00  346.027466  595.520020  ...  60.094044  96.885109
# 2023-12-29 00:00:00+00:00  345.358246  596.599976  ...  60.113468  96.682037
#
# Ticker                          XRAY         XYL         YUM         ZBH  \
# Date
# 2020-01-02 00:00:00+00:00  53.422768   75.451172   93.541397  139.626221
# 2020-01-03 00:00:00+00:00  52.831589   75.895309   93.248436  139.261230
# 2020-01-06 00:00:00+00:00  53.122486   75.403938   93.193504  138.456451
# 2020-01-07 00:00:00+00:00  53.403999   75.120476   93.358307  138.334763
# 2020-01-08 00:00:00+00:00  53.967037   75.375587   93.523094  139.991226
# ...                              ...         ...         ...         ...
# 2023-12-22 00:00:00+00:00  34.478691  111.722412  128.081024  119.562080
# 2023-12-26 00:00:00+00:00  34.791954  112.694427  128.337189  120.655167
# 2023-12-27 00:00:00+00:00  34.880062  113.448242  128.908630  120.366989
# 2023-12-28 00:00:00+00:00  34.978340  113.388725  128.593369  120.863838
# 2023-12-29 00:00:00+00:00  34.978340  113.428398  128.731293  120.933403
#
# Ticker                           ZBRA       ZION          ZS         ZTS
# Date
# 2020-01-02 00:00:00+00:00  259.140015  44.052658   47.330002  129.208878
# 2020-01-03 00:00:00+00:00  256.049988  43.431015   47.380001  129.228149
# 2020-01-06 00:00:00+00:00  258.010010  42.901775   48.700001  128.236053
# 2020-01-07 00:00:00+00:00  256.470001  42.641357   48.400002  128.669464
# 2020-01-08 00:00:00+00:00  247.639999  43.061386   50.750000  128.390137
# ...                               ...        ...         ...         ...
# 2023-12-22 00:00:00+00:00  269.410004  42.445377  221.679993  193.067825
# 2023-12-26 00:00:00+00:00  275.500000  43.294289  224.589996  193.582733
# 2023-12-27 00:00:00+00:00  275.790009  42.937359  225.020004  194.968994
# 2023-12-28 00:00:00+00:00  275.350006  43.082058  224.440002  195.226456
# 2023-12-29 00:00:00+00:00  273.329987  42.319969  221.559998  195.434387
#
# [1030 rows x 600 columns]

# %% [markdown]
# ### Расчет метрик: равномерный бейзлайн $\\$

# %%
mean_returns.shape
# Out:
# (600,)

# %%
import matplotlib.pyplot as plt
plt.hist(mean_returns, bins=100)
plt.show()

# %%
returns = price_data.pct_change()
returns = returns.iloc[1:]
# display(returns)
num_assets = price_data.shape[1]
weights = np.full(num_assets, 1 / num_assets) # равномерный бейзлайн
print(weights.shape)
print(returns.shape)
# print(weights)
# nan_columns_count = returns.isna().any().sum()
# nan_columns = returns.columns[returns.isna().any()].tolist()
# print(f"Столбцы, содержащие хотя бы одно NaN: {nan_columns}")

# print(f"Количество столбцов с NaN: {nan_columns_count}")
# print(returns.isna().sum())
# print(returns.describe())
mean_returns = returns.mean(axis=0)
portfolio_returns = np.dot(weights, mean_returns)
# print(portfolio_returns)

cov_matrix = returns.cov()
portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
risk_free_rate = 0.02
sharpe_ratio = (portfolio_returns - risk_free_rate) / portfolio_volatility

print(f"Средняя доходность портфеля: {portfolio_returns * 100}")
print(f"Волатильность портфеля: {portfolio_volatility}")
print(f"Коэффициент Шарпа: {sharpe_ratio:.2f}")
# Out:
# (600,)
# (1029, 600)
# Средняя доходность портфеля: 0.06186594881744995
# Волатильность портфеля: 0.014312071950566198
# Коэффициент Шарпа: -1.35

# %%
random_weights = np.random.rand(num_assets) 
random_weights /= random_weights.sum()

mean_returns = returns.mean(axis=0)
portfolio_returns = np.dot(random_weights, mean_returns)

cov_matrix = returns.cov()
portfolio_volatility = np.sqrt(np.dot(random_weights.T, np.dot(cov_matrix, random_weights)))
risk_free_rate = 0.02
sharpe_ratio = (portfolio_returns - risk_free_rate) / portfolio_volatility

print(f"Средняя доходность портфеля: {portfolio_returns * 100}")
print(f"Волатильность портфеля: {portfolio_volatility}")
print(f"Коэффициент Шарпа: {sharpe_ratio:.2f}")
# Out:
# Средняя доходность портфеля: 0.062224434299107956
# Волатильность портфеля: 0.01432569115016874
# Коэффициент Шарпа: -1.35
